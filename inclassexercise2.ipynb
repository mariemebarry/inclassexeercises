# %%
# Marieme Barry
# Advanced Python for Business

# %%
# import pandas package
import pandas as pd
df = pd.read_excel('EcarSalesByCountryAndYear2.xlsx')
df
# Out:
#     Title:                        Electric car use by country
# 0  Source:  https://en.wikipedia.org/wiki/Electric_car_use...
# 1    Date:                                2023-01-27 00:00:00

# %%
# refine the call using sheet name parameter

df = pd.read_excel('EcarSalesByCountryAndYear2.xlsx', sheet_name = 'EcarSalesByCountryAndYear')
df
# Out:
#           Country  Sales2021  Sales2020  Sales2019  Sales2018  Sales2017
# 0          Canada      87700      51376      50960      44150      18746
# 1           China    3334000    1246000    1204000    1016002     579000
# 2          France     315978     194881      69466      53745      42799
# 3         Germany     681410     394632     108839      67504      54492
# 4           Japan      44296      29000      43867      52013      54100
# 5     Netherlands      95464      89362      67520      29187      11085
# 6          Norway     167949     113588      88443      86290      71737
# 7          Sweden     138033      96054      41784      29909      19793
# 8  United Kingdom     305281     175082      72584      59911      49182
# 9   United States     607567     297939     329528     361307     199818

# %%
# use country as index for dataframe

df = pd.read_excel('EcarSalesByCountryAndYear2.xlsx', sheet_name = 'EcarSalesByCountryAndYear',
                   index_col = 'Country')
df
# Out:
#                 Sales2021  Sales2020  Sales2019  Sales2018  Sales2017
# Country
# Canada              87700      51376      50960      44150      18746
# China             3334000    1246000    1204000    1016002     579000
# France             315978     194881      69466      53745      42799
# Germany            681410     394632     108839      67504      54492
# Japan               44296      29000      43867      52013      54100
# Netherlands         95464      89362      67520      29187      11085
# Norway             167949     113588      88443      86290      71737
# Sweden             138033      96054      41784      29909      19793
# United Kingdom     305281     175082      72584      59911      49182
# United States      607567     297939     329528     361307     199818
